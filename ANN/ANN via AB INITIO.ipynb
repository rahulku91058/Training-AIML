# %%
import random
from math import exp

## Learning addition of two small numbers , preferably 2 digit numbers.

# Normalize dataset
def normalize_dataset(dataset):
	min_max = [[min(column), max(column)] for column in zip(*dataset)]
	for row in dataset:
		for i in range(len(row)):
			row[i] = (row[i] - min_max[i][0]) / (min_max[i][1] - min_max[i][0])
	return min_max

# Denormalize a value
def denormalize(value, min_val, max_val):
	return value * (max_val - min_val) + min_val

# Initialize a network
def initialize_network(n_inputs, n_hidden, n_outputs):
	network = list()
	hidden_layer = [{'weights': [random.random() for _ in range(n_inputs + 1)]} for _ in range(n_hidden)]
	network.append(hidden_layer)
	output_layer = [{'weights': [random.random() for _ in range(n_hidden + 1)]} for _ in range(n_outputs)]
	network.append(output_layer)
	return network

# Calculate neuron activation for an input
def activate(weights, inputs):
	activation = weights[-1]
	for i in range(len(weights) - 1):
		activation += weights[i] * inputs[i]
	return activation

# Transfer neuron activation (sigmoid)
def transfer(activation):
	return 1.0 / (1.0 + exp(-activation))

# Forward propagate input to a network output
def forward_propagate(network, row):
	inputs = row[:-1]
	for layer in network:
		new_inputs = []
		for neuron in layer:
			activation = activate(neuron['weights'], inputs)
			neuron['output'] = transfer(activation)
			new_inputs.append(neuron['output'])
		inputs = new_inputs
	return inputs

# Calculate the derivative of a neuron output
def transfer_derivative(output):
	return output * (1.0 - output)

# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
	for i in reversed(range(len(network))):
		layer = network[i]
		errors = list()
		if i != len(network) - 1:
			for j in range(len(layer)):
				error = 0.0
				for neuron in network[i + 1]:
					error += (neuron['weights'][j] * neuron['delta'])
				errors.append(error)
		else:
			for j in range(len(layer)):
				neuron = layer[j]
				errors.append(neuron['output'] - expected[j])
		for j in range(len(layer)):
			neuron = layer[j]
			neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# Update network weights with error
def update_weights(network, row, l_rate):
	for i in range(len(network)):
		inputs = row[:-1] if i == 0 else [neuron['output'] for neuron in network[i - 1]]
		for neuron in network[i]:
			for j in range(len(inputs)):
				neuron['weights'][j] -= l_rate * neuron['delta'] * inputs[j]
			neuron['weights'][-1] -= l_rate * neuron['delta']

# Train a network for a fixed number of epochs
def train_network(network, train, l_rate, n_epoch, n_outputs):
	for epoch in range(n_epoch):
		sum_error = 0
		for row in train:
			outputs = forward_propagate(network, row)
			expected = [row[-1]]
			sum_error += (expected[0] - outputs[0])**2
			backward_propagate_error(network, expected)
			update_weights(network, row, l_rate)
		print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# Dataset
dataset = [
	[12, 23, 35],
	[25, 70, 95],
	[23, 55, 78],
	[56, 98, 154],
	[23, 78, 101],
	[95, 65, 160],
	[69, 92, 161],
	[40, 70, 110],
	[87, 90, 177],
	[94, 12, 106]
]

# Network parameters
n_inputs = 2
n_hidden = 8
n_outputs = 1
l_rate = 0.05
n_epoch = 3550

# Normalize the dataset
min_max = normalize_dataset(dataset)

# Initialize and train the network
network = initialize_network(n_inputs, n_hidden, n_outputs)
train_network(network, dataset, l_rate, n_epoch, n_outputs)

# Test the network after training
print("\nTesting the network:")
for row in dataset:
	# Forward propagate and get the predicted output
	outputs = forward_propagate(network, row)
	# Denormalize the predicted output
	predicted = denormalize(outputs[0], min_max[-1][0], min_max[-1][1])
	print(f"Expected={denormalize(row[-1], min_max[-1][0], min_max[-1][1])}, Predicted={predicted:.3f}")
# Out:
# >epoch=0, lrate=0.050, error=2.298
# >epoch=1, lrate=0.050, error=2.286
# >epoch=2, lrate=0.050, error=2.274
# >epoch=3, lrate=0.050, error=2.262
# >epoch=4, lrate=0.050, error=2.248
# >epoch=5, lrate=0.050, error=2.234
# >epoch=6, lrate=0.050, error=2.218
# >epoch=7, lrate=0.050, error=2.202
# >epoch=8, lrate=0.050, error=2.184
# >epoch=9, lrate=0.050, error=2.165
# >epoch=10, lrate=0.050, error=2.145
# >epoch=11, lrate=0.050, error=2.123
# >epoch=12, lrate=0.050, error=2.100
# >epoch=13, lrate=0.050, error=2.074
# >epoch=14, lrate=0.050, error=2.047
# >epoch=15, lrate=0.050, error=2.018
# >epoch=16, lrate=0.050, error=1.987
# >epoch=17, lrate=0.050, error=1.953
# >epoch=18, lrate=0.050, error=1.917
# >epoch=19, lrate=0.050, error=1.877
# >epoch=20, lrate=0.050, error=1.835
# >epoch=21, lrate=0.050, error=1.791
# >epoch=22, lrate=0.050, error=1.743
# >epoch=23, lrate=0.050, error=1.692
# >epoch=24, lrate=0.050, error=1.639
# >epoch=25, lrate=0.050, error=1.583
# >epoch=26, lrate=0.050, error=1.525
# >epoch=27, lrate=0.050, error=1.466
# >epoch=28, lrate=0.050, error=1.407
# >epoch=29, lrate=0.050, error=1.348
# >epoch=30, lrate=0.050, error=1.290
# >epoch=31, lrate=0.050, error=1.235
# >epoch=32, lrate=0.050, error=1.184
# >epoch=33, lrate=0.050, error=1.136
# >epoch=34, lrate=0.050, error=1.093
# >epoch=35, lrate=0.050, error=1.056
# >epoch=36, lrate=0.050, error=1.023
# >epoch=37, lrate=0.050, error=0.995
# >epoch=38, lrate=0.050, error=0.972
# >epoch=39, lrate=0.050, error=0.952
# >epoch=40, lrate=0.050, error=0.937
# >epoch=41, lrate=0.050, error=0.924
# >epoch=42, lrate=0.050, error=0.914
# >epoch=43, lrate=0.050, error=0.905
# >epoch=44, lrate=0.050, error=0.899
# >epoch=45, lrate=0.050, error=0.893
# >epoch=46, lrate=0.050, error=0.889
# >epoch=47, lrate=0.050, error=0.885
# >epoch=48, lrate=0.050, error=0.883
# >epoch=49, lrate=0.050, error=0.880
# >epoch=50, lrate=0.050, error=0.878
# >epoch=51, lrate=0.050, error=0.877
# >epoch=52, lrate=0.050, error=0.875
# >epoch=53, lrate=0.050, error=0.874
# >epoch=54, lrate=0.050, error=0.873
# >epoch=55, lrate=0.050, error=0.872
# >epoch=56, lrate=0.050, error=0.871
# >epoch=57, lrate=0.050, error=0.870
# >epoch=58, lrate=0.050, error=0.870
# >epoch=59, lrate=0.050, error=0.869
# >epoch=60, lrate=0.050, error=0.868
# >epoch=61, lrate=0.050, error=0.868
# >epoch=62, lrate=0.050, error=0.867
# >epoch=63, lrate=0.050, error=0.866
# >epoch=64, lrate=0.050, error=0.866
# >epoch=65, lrate=0.050, error=0.865
# >epoch=66, lrate=0.050, error=0.865
# >epoch=67, lrate=0.050, error=0.864
# >epoch=68, lrate=0.050, error=0.863
# >epoch=69, lrate=0.050, error=0.863
# >epoch=70, lrate=0.050, error=0.862
# >epoch=71, lrate=0.050, error=0.862
# >epoch=72, lrate=0.050, error=0.861
# >epoch=73, lrate=0.050, error=0.861
# >epoch=74, lrate=0.050, error=0.860
# >epoch=75, lrate=0.050, error=0.860
# >epoch=76, lrate=0.050, error=0.859
# >epoch=77, lrate=0.050, error=0.859
# >epoch=78, lrate=0.050, error=0.858
# >epoch=79, lrate=0.050, error=0.857
# >epoch=80, lrate=0.050, error=0.857
# >epoch=81, lrate=0.050, error=0.856
# >epoch=82, lrate=0.050, error=0.856
# >epoch=83, lrate=0.050, error=0.855
# >epoch=84, lrate=0.050, error=0.855
# >epoch=85, lrate=0.050, error=0.854
# >epoch=86, lrate=0.050, error=0.854
# >epoch=87, lrate=0.050, error=0.853
# >epoch=88, lrate=0.050, error=0.853
# >epoch=89, lrate=0.050, error=0.852
# >epoch=90, lrate=0.050, error=0.852
# >epoch=91, lrate=0.050, error=0.851
# >epoch=92, lrate=0.050, error=0.851
# >epoch=93, lrate=0.050, error=0.850
# >epoch=94, lrate=0.050, error=0.849
# >epoch=95, lrate=0.050, error=0.849
# >epoch=96, lrate=0.050, error=0.848
# >epoch=97, lrate=0.050, error=0.848
# >epoch=98, lrate=0.050, error=0.847
# >epoch=99, lrate=0.050, error=0.847
# >epoch=100, lrate=0.050, error=0.846
# >epoch=101, lrate=0.050, error=0.846
# >epoch=102, lrate=0.050, error=0.845
# >epoch=103, lrate=0.050, error=0.845
# >epoch=104, lrate=0.050, error=0.844
# >epoch=105, lrate=0.050, error=0.844
# >epoch=106, lrate=0.050, error=0.843
# >epoch=107, lrate=0.050, error=0.843
# >epoch=108, lrate=0.050, error=0.842
# >epoch=109, lrate=0.050, error=0.841
# >epoch=110, lrate=0.050, error=0.841
# >epoch=111, lrate=0.050, error=0.840
# >epoch=112, lrate=0.050, error=0.840
# >epoch=113, lrate=0.050, error=0.839
# >epoch=114, lrate=0.050, error=0.839
# >epoch=115, lrate=0.050, error=0.838
# >epoch=116, lrate=0.050, error=0.838
# >epoch=117, lrate=0.050, error=0.837
# >epoch=118, lrate=0.050, error=0.837
# >epoch=119, lrate=0.050, error=0.836
# >epoch=120, lrate=0.050, error=0.836
# >epoch=121, lrate=0.050, error=0.835
# >epoch=122, lrate=0.050, error=0.835
# >epoch=123, lrate=0.050, error=0.834
# >epoch=124, lrate=0.050, error=0.834
# >epoch=125, lrate=0.050, error=0.833
# >epoch=126, lrate=0.050, error=0.832
# >epoch=127, lrate=0.050, error=0.832
# >epoch=128, lrate=0.050, error=0.831
# >epoch=129, lrate=0.050, error=0.831
# >epoch=130, lrate=0.050, error=0.830
# >epoch=131, lrate=0.050, error=0.830
# >epoch=132, lrate=0.050, error=0.829
# >epoch=133, lrate=0.050, error=0.829
# >epoch=134, lrate=0.050, error=0.828
# >epoch=135, lrate=0.050, error=0.828
# >epoch=136, lrate=0.050, error=0.827
# >epoch=137, lrate=0.050, error=0.827
# >epoch=138, lrate=0.050, error=0.826
# >epoch=139, lrate=0.050, error=0.825
# >epoch=140, lrate=0.050, error=0.825
# >epoch=141, lrate=0.050, error=0.824
# >epoch=142, lrate=0.050, error=0.824
# >epoch=143, lrate=0.050, error=0.823
# >epoch=144, lrate=0.050, error=0.823
# >epoch=145, lrate=0.050, error=0.822
# >epoch=146, lrate=0.050, error=0.822
# >epoch=147, lrate=0.050, error=0.821
# >epoch=148, lrate=0.050, error=0.821
# >epoch=149, lrate=0.050, error=0.820
# >epoch=150, lrate=0.050, error=0.820
# >epoch=151, lrate=0.050, error=0.819
# >epoch=152, lrate=0.050, error=0.818
# >epoch=153, lrate=0.050, error=0.818
# >epoch=154, lrate=0.050, error=0.817
# >epoch=155, lrate=0.050, error=0.817
# >epoch=156, lrate=0.050, error=0.816
# >epoch=157, lrate=0.050, error=0.816
# >epoch=158, lrate=0.050, error=0.815
# >epoch=159, lrate=0.050, error=0.815
# >epoch=160, lrate=0.050, error=0.814
# >epoch=161, lrate=0.050, error=0.814
# >epoch=162, lrate=0.050, error=0.813
# >epoch=163, lrate=0.050, error=0.813
# >epoch=164, lrate=0.050, error=0.812
# >epoch=165, lrate=0.050, error=0.811
# >epoch=166, lrate=0.050, error=0.811
# >epoch=167, lrate=0.050, error=0.810
# >epoch=168, lrate=0.050, error=0.810
# >epoch=169, lrate=0.050, error=0.809
# >epoch=170, lrate=0.050, error=0.809
# >epoch=171, lrate=0.050, error=0.808
# >epoch=172, lrate=0.050, error=0.808
# >epoch=173, lrate=0.050, error=0.807
# >epoch=174, lrate=0.050, error=0.807
# >epoch=175, lrate=0.050, error=0.806
# >epoch=176, lrate=0.050, error=0.805
# >epoch=177, lrate=0.050, error=0.805
# >epoch=178, lrate=0.050, error=0.804
# >epoch=179, lrate=0.050, error=0.804
# >epoch=180, lrate=0.050, error=0.803
# >epoch=181, lrate=0.050, error=0.803
# >epoch=182, lrate=0.050, error=0.802
# >epoch=183, lrate=0.050, error=0.802
# >epoch=184, lrate=0.050, error=0.801
# >epoch=185, lrate=0.050, error=0.800
# >epoch=186, lrate=0.050, error=0.800
# >epoch=187, lrate=0.050, error=0.799
# >epoch=188, lrate=0.050, error=0.799
# >epoch=189, lrate=0.050, error=0.798
# >epoch=190, lrate=0.050, error=0.798
# >epoch=191, lrate=0.050, error=0.797
# >epoch=192, lrate=0.050, error=0.797
# >epoch=193, lrate=0.050, error=0.796
# >epoch=194, lrate=0.050, error=0.796
# >epoch=195, lrate=0.050, error=0.795
# >epoch=196, lrate=0.050, error=0.794
# >epoch=197, lrate=0.050, error=0.794
# >epoch=198, lrate=0.050, error=0.793
# >epoch=199, lrate=0.050, error=0.793
# >epoch=200, lrate=0.050, error=0.792
# >epoch=201, lrate=0.050, error=0.792
# >epoch=202, lrate=0.050, error=0.791
# >epoch=203, lrate=0.050, error=0.790
# >epoch=204, lrate=0.050, error=0.790
# >epoch=205, lrate=0.050, error=0.789
# >epoch=206, lrate=0.050, error=0.789
# >epoch=207, lrate=0.050, error=0.788
# >epoch=208, lrate=0.050, error=0.788
# >epoch=209, lrate=0.050, error=0.787
# >epoch=210, lrate=0.050, error=0.787
# >epoch=211, lrate=0.050, error=0.786
# >epoch=212, lrate=0.050, error=0.785
# >epoch=213, lrate=0.050, error=0.785
# >epoch=214, lrate=0.050, error=0.784
# >epoch=215, lrate=0.050, error=0.784
# >epoch=216, lrate=0.050, error=0.783
# >epoch=217, lrate=0.050, error=0.783
# >epoch=218, lrate=0.050, error=0.782
# >epoch=219, lrate=0.050, error=0.781
# >epoch=220, lrate=0.050, error=0.781
# >epoch=221, lrate=0.050, error=0.780
# >epoch=222, lrate=0.050, error=0.780
# >epoch=223, lrate=0.050, error=0.779
# >epoch=224, lrate=0.050, error=0.779
# >epoch=225, lrate=0.050, error=0.778
# >epoch=226, lrate=0.050, error=0.777
# >epoch=227, lrate=0.050, error=0.777
# >epoch=228, lrate=0.050, error=0.776
# >epoch=229, lrate=0.050, error=0.776
# >epoch=230, lrate=0.050, error=0.775
# >epoch=231, lrate=0.050, error=0.775
# >epoch=232, lrate=0.050, error=0.774
# >epoch=233, lrate=0.050, error=0.773
# >epoch=234, lrate=0.050, error=0.773
# >epoch=235, lrate=0.050, error=0.772
# >epoch=236, lrate=0.050, error=0.772
# >epoch=237, lrate=0.050, error=0.771
# >epoch=238, lrate=0.050, error=0.770
# >epoch=239, lrate=0.050, error=0.770
# >epoch=240, lrate=0.050, error=0.769
# >epoch=241, lrate=0.050, error=0.769
# >epoch=242, lrate=0.050, error=0.768
# >epoch=243, lrate=0.050, error=0.768
# >epoch=244, lrate=0.050, error=0.767
# >epoch=245, lrate=0.050, error=0.766
# >epoch=246, lrate=0.050, error=0.766
# >epoch=247, lrate=0.050, error=0.765
# >epoch=248, lrate=0.050, error=0.765
# >epoch=249, lrate=0.050, error=0.764
# >epoch=250, lrate=0.050, error=0.763
# >epoch=251, lrate=0.050, error=0.763
# >epoch=252, lrate=0.050, error=0.762
# >epoch=253, lrate=0.050, error=0.762
# >epoch=254, lrate=0.050, error=0.761
# >epoch=255, lrate=0.050, error=0.760
# >epoch=256, lrate=0.050, error=0.760
# >epoch=257, lrate=0.050, error=0.759
# >epoch=258, lrate=0.050, error=0.759
# >epoch=259, lrate=0.050, error=0.758
# >epoch=260, lrate=0.050, error=0.758
# >epoch=261, lrate=0.050, error=0.757
# >epoch=262, lrate=0.050, error=0.756
# >epoch=263, lrate=0.050, error=0.756
# >epoch=264, lrate=0.050, error=0.755
# >epoch=265, lrate=0.050, error=0.755
# >epoch=266, lrate=0.050, error=0.754
# >epoch=267, lrate=0.050, error=0.753
# >epoch=268, lrate=0.050, error=0.753
# >epoch=269, lrate=0.050, error=0.752
# >epoch=270, lrate=0.050, error=0.751
# >epoch=271, lrate=0.050, error=0.751
# >epoch=272, lrate=0.050, error=0.750
# >epoch=273, lrate=0.050, error=0.750
# >epoch=274, lrate=0.050, error=0.749
# >epoch=275, lrate=0.050, error=0.748
# >epoch=276, lrate=0.050, error=0.748
# >epoch=277, lrate=0.050, error=0.747
# >epoch=278, lrate=0.050, error=0.747
# >epoch=279, lrate=0.050, error=0.746
# >epoch=280, lrate=0.050, error=0.745
# >epoch=281, lrate=0.050, error=0.745
# >epoch=282, lrate=0.050, error=0.744
# >epoch=283, lrate=0.050, error=0.744
# >epoch=284, lrate=0.050, error=0.743
# >epoch=285, lrate=0.050, error=0.742
# >epoch=286, lrate=0.050, error=0.742
# >epoch=287, lrate=0.050, error=0.741
# >epoch=288, lrate=0.050, error=0.740
# >epoch=289, lrate=0.050, error=0.740
# >epoch=290, lrate=0.050, error=0.739
# >epoch=291, lrate=0.050, error=0.739
# >epoch=292, lrate=0.050, error=0.738
# >epoch=293, lrate=0.050, error=0.737
# >epoch=294, lrate=0.050, error=0.737
# >epoch=295, lrate=0.050, error=0.736
# >epoch=296, lrate=0.050, error=0.735
# >epoch=297, lrate=0.050, error=0.735
# >epoch=298, lrate=0.050, error=0.734
# >epoch=299, lrate=0.050, error=0.734
# >epoch=300, lrate=0.050, error=0.733
# >epoch=301, lrate=0.050, error=0.732
# >epoch=302, lrate=0.050, error=0.732
# >epoch=303, lrate=0.050, error=0.731
# >epoch=304, lrate=0.050, error=0.730
# >epoch=305, lrate=0.050, error=0.730
# >epoch=306, lrate=0.050, error=0.729
# >epoch=307, lrate=0.050, error=0.729
# >epoch=308, lrate=0.050, error=0.728
# >epoch=309, lrate=0.050, error=0.727
# >epoch=310, lrate=0.050, error=0.727
# >epoch=311, lrate=0.050, error=0.726
# >epoch=312, lrate=0.050, error=0.725
# >epoch=313, lrate=0.050, error=0.725
# >epoch=314, lrate=0.050, error=0.724
# >epoch=315, lrate=0.050, error=0.723
# >epoch=316, lrate=0.050, error=0.723
# >epoch=317, lrate=0.050, error=0.722
# >epoch=318, lrate=0.050, error=0.721
# >epoch=319, lrate=0.050, error=0.721
# >epoch=320, lrate=0.050, error=0.720
# >epoch=321, lrate=0.050, error=0.720
# >epoch=322, lrate=0.050, error=0.719
# >epoch=323, lrate=0.050, error=0.718
# >epoch=324, lrate=0.050, error=0.718
# >epoch=325, lrate=0.050, error=0.717
# >epoch=326, lrate=0.050, error=0.716
# >epoch=327, lrate=0.050, error=0.716
# >epoch=328, lrate=0.050, error=0.715
# >epoch=329, lrate=0.050, error=0.714
# >epoch=330, lrate=0.050, error=0.714
# >epoch=331, lrate=0.050, error=0.713
# >epoch=332, lrate=0.050, error=0.712
# >epoch=333, lrate=0.050, error=0.712
# >epoch=334, lrate=0.050, error=0.711
# >epoch=335, lrate=0.050, error=0.710
# >epoch=336, lrate=0.050, error=0.710
# >epoch=337, lrate=0.050, error=0.709
# >epoch=338, lrate=0.050, error=0.708
# >epoch=339, lrate=0.050, error=0.708
# >epoch=340, lrate=0.050, error=0.707
# >epoch=341, lrate=0.050, error=0.706
# >epoch=342, lrate=0.050, error=0.706
# >epoch=343, lrate=0.050, error=0.705
# >epoch=344, lrate=0.050, error=0.704
# >epoch=345, lrate=0.050, error=0.704
# >epoch=346, lrate=0.050, error=0.703
# >epoch=347, lrate=0.050, error=0.702
# >epoch=348, lrate=0.050, error=0.702
# >epoch=349, lrate=0.050, error=0.701
# >epoch=350, lrate=0.050, error=0.700
# >epoch=351, lrate=0.050, error=0.700
# >epoch=352, lrate=0.050, error=0.699
# >epoch=353, lrate=0.050, error=0.698
# >epoch=354, lrate=0.050, error=0.698
# >epoch=355, lrate=0.050, error=0.697
# >epoch=356, lrate=0.050, error=0.696
# >epoch=357, lrate=0.050, error=0.696
# >epoch=358, lrate=0.050, error=0.695
# >epoch=359, lrate=0.050, error=0.694
# >epoch=360, lrate=0.050, error=0.693
# >epoch=361, lrate=0.050, error=0.693
# >epoch=362, lrate=0.050, error=0.692
# >epoch=363, lrate=0.050, error=0.691
# >epoch=364, lrate=0.050, error=0.691
# >epoch=365, lrate=0.050, error=0.690
# >epoch=366, lrate=0.050, error=0.689
# >epoch=367, lrate=0.050, error=0.689
# >epoch=368, lrate=0.050, error=0.688
# >epoch=369, lrate=0.050, error=0.687
# >epoch=370, lrate=0.050, error=0.687
# >epoch=371, lrate=0.050, error=0.686
# >epoch=372, lrate=0.050, error=0.685
# >epoch=373, lrate=0.050, error=0.684
# >epoch=374, lrate=0.050, error=0.684
# >epoch=375, lrate=0.050, error=0.683
# >epoch=376, lrate=0.050, error=0.682
# >epoch=377, lrate=0.050, error=0.682
# >epoch=378, lrate=0.050, error=0.681
# >epoch=379, lrate=0.050, error=0.680
# >epoch=380, lrate=0.050, error=0.680
# >epoch=381, lrate=0.050, error=0.679
# >epoch=382, lrate=0.050, error=0.678
# >epoch=383, lrate=0.050, error=0.677
# >epoch=384, lrate=0.050, error=0.677
# >epoch=385, lrate=0.050, error=0.676
# >epoch=386, lrate=0.050, error=0.675
# >epoch=387, lrate=0.050, error=0.675
# >epoch=388, lrate=0.050, error=0.674
# >epoch=389, lrate=0.050, error=0.673
# >epoch=390, lrate=0.050, error=0.672
# >epoch=391, lrate=0.050, error=0.672
# >epoch=392, lrate=0.050, error=0.671
# >epoch=393, lrate=0.050, error=0.670
# >epoch=394, lrate=0.050, error=0.670
# >epoch=395, lrate=0.050, error=0.669
# >epoch=396, lrate=0.050, error=0.668
# >epoch=397, lrate=0.050, error=0.667
# >epoch=398, lrate=0.050, error=0.667
# >epoch=399, lrate=0.050, error=0.666
# >epoch=400, lrate=0.050, error=0.665
# >epoch=401, lrate=0.050, error=0.665
# >epoch=402, lrate=0.050, error=0.664
# >epoch=403, lrate=0.050, error=0.663
# >epoch=404, lrate=0.050, error=0.662
# >epoch=405, lrate=0.050, error=0.662
# >epoch=406, lrate=0.050, error=0.661
# >epoch=407, lrate=0.050, error=0.660
# >epoch=408, lrate=0.050, error=0.659
# >epoch=409, lrate=0.050, error=0.659
# >epoch=410, lrate=0.050, error=0.658
# >epoch=411, lrate=0.050, error=0.657
# >epoch=412, lrate=0.050, error=0.656
# >epoch=413, lrate=0.050, error=0.656
# >epoch=414, lrate=0.050, error=0.655
# >epoch=415, lrate=0.050, error=0.654
# >epoch=416, lrate=0.050, error=0.654
# >epoch=417, lrate=0.050, error=0.653
# >epoch=418, lrate=0.050, error=0.652
# >epoch=419, lrate=0.050, error=0.651
# >epoch=420, lrate=0.050, error=0.651
# >epoch=421, lrate=0.050, error=0.650
# >epoch=422, lrate=0.050, error=0.649
# >epoch=423, lrate=0.050, error=0.648
# >epoch=424, lrate=0.050, error=0.648
# >epoch=425, lrate=0.050, error=0.647
# >epoch=426, lrate=0.050, error=0.646
# >epoch=427, lrate=0.050, error=0.645
# >epoch=428, lrate=0.050, error=0.645
# >epoch=429, lrate=0.050, error=0.644
# >epoch=430, lrate=0.050, error=0.643
# >epoch=431, lrate=0.050, error=0.642
# >epoch=432, lrate=0.050, error=0.642
# >epoch=433, lrate=0.050, error=0.641
# >epoch=434, lrate=0.050, error=0.640
# >epoch=435, lrate=0.050, error=0.639
# >epoch=436, lrate=0.050, error=0.639
# >epoch=437, lrate=0.050, error=0.638
# >epoch=438, lrate=0.050, error=0.637
# >epoch=439, lrate=0.050, error=0.636
# >epoch=440, lrate=0.050, error=0.635
# >epoch=441, lrate=0.050, error=0.635
# >epoch=442, lrate=0.050, error=0.634
# >epoch=443, lrate=0.050, error=0.633
# >epoch=444, lrate=0.050, error=0.632
# >epoch=445, lrate=0.050, error=0.632
# >epoch=446, lrate=0.050, error=0.631
# >epoch=447, lrate=0.050, error=0.630
# >epoch=448, lrate=0.050, error=0.629
# >epoch=449, lrate=0.050, error=0.629
# >epoch=450, lrate=0.050, error=0.628
# >epoch=451, lrate=0.050, error=0.627
# >epoch=452, lrate=0.050, error=0.626
# >epoch=453, lrate=0.050, error=0.625
# >epoch=454, lrate=0.050, error=0.625
# >epoch=455, lrate=0.050, error=0.624
# >epoch=456, lrate=0.050, error=0.623
# >epoch=457, lrate=0.050, error=0.622
# >epoch=458, lrate=0.050, error=0.622
# >epoch=459, lrate=0.050, error=0.621
# >epoch=460, lrate=0.050, error=0.620
# >epoch=461, lrate=0.050, error=0.619
# >epoch=462, lrate=0.050, error=0.618
# >epoch=463, lrate=0.050, error=0.618
# >epoch=464, lrate=0.050, error=0.617
# >epoch=465, lrate=0.050, error=0.616
# >epoch=466, lrate=0.050, error=0.615
# >epoch=467, lrate=0.050, error=0.615
# >epoch=468, lrate=0.050, error=0.614
# >epoch=469, lrate=0.050, error=0.613
# >epoch=470, lrate=0.050, error=0.612
# >epoch=471, lrate=0.050, error=0.611
# >epoch=472, lrate=0.050, error=0.611
# >epoch=473, lrate=0.050, error=0.610
# >epoch=474, lrate=0.050, error=0.609
# >epoch=475, lrate=0.050, error=0.608
# >epoch=476, lrate=0.050, error=0.607
# >epoch=477, lrate=0.050, error=0.607
# >epoch=478, lrate=0.050, error=0.606
# >epoch=479, lrate=0.050, error=0.605
# >epoch=480, lrate=0.050, error=0.604
# >epoch=481, lrate=0.050, error=0.603
# >epoch=482, lrate=0.050, error=0.603
# >epoch=483, lrate=0.050, error=0.602
# >epoch=484, lrate=0.050, error=0.601
# >epoch=485, lrate=0.050, error=0.600
# >epoch=486, lrate=0.050, error=0.599
# >epoch=487, lrate=0.050, error=0.599
# >epoch=488, lrate=0.050, error=0.598
# >epoch=489, lrate=0.050, error=0.597
# >epoch=490, lrate=0.050, error=0.596
# >epoch=491, lrate=0.050, error=0.595
# >epoch=492, lrate=0.050, error=0.595
# >epoch=493, lrate=0.050, error=0.594
# >epoch=494, lrate=0.050, error=0.593
# >epoch=495, lrate=0.050, error=0.592
# >epoch=496, lrate=0.050, error=0.591
# >epoch=497, lrate=0.050, error=0.590
# >epoch=498, lrate=0.050, error=0.590
# >epoch=499, lrate=0.050, error=0.589
# >epoch=500, lrate=0.050, error=0.588
# >epoch=501, lrate=0.050, error=0.587
# >epoch=502, lrate=0.050, error=0.586
# >epoch=503, lrate=0.050, error=0.586
# >epoch=504, lrate=0.050, error=0.585
# >epoch=505, lrate=0.050, error=0.584
# >epoch=506, lrate=0.050, error=0.583
# >epoch=507, lrate=0.050, error=0.582
# >epoch=508, lrate=0.050, error=0.581
# >epoch=509, lrate=0.050, error=0.581
# >epoch=510, lrate=0.050, error=0.580
# >epoch=511, lrate=0.050, error=0.579
# >epoch=512, lrate=0.050, error=0.578
# >epoch=513, lrate=0.050, error=0.577
# >epoch=514, lrate=0.050, error=0.577
# >epoch=515, lrate=0.050, error=0.576
# >epoch=516, lrate=0.050, error=0.575
# >epoch=517, lrate=0.050, error=0.574
# >epoch=518, lrate=0.050, error=0.573
# >epoch=519, lrate=0.050, error=0.572
# >epoch=520, lrate=0.050, error=0.572
# >epoch=521, lrate=0.050, error=0.571
# >epoch=522, lrate=0.050, error=0.570
# >epoch=523, lrate=0.050, error=0.569
# >epoch=524, lrate=0.050, error=0.568
# >epoch=525, lrate=0.050, error=0.567
# >epoch=526, lrate=0.050, error=0.567
# >epoch=527, lrate=0.050, error=0.566
# >epoch=528, lrate=0.050, error=0.565
# >epoch=529, lrate=0.050, error=0.564
# >epoch=530, lrate=0.050, error=0.563
# >epoch=531, lrate=0.050, error=0.562
# >epoch=532, lrate=0.050, error=0.562
# >epoch=533, lrate=0.050, error=0.561
# >epoch=534, lrate=0.050, error=0.560
# >epoch=535, lrate=0.050, error=0.559
# >epoch=536, lrate=0.050, error=0.558
# >epoch=537, lrate=0.050, error=0.557
# >epoch=538, lrate=0.050, error=0.557
# >epoch=539, lrate=0.050, error=0.556
# >epoch=540, lrate=0.050, error=0.555
# >epoch=541, lrate=0.050, error=0.554
# >epoch=542, lrate=0.050, error=0.553
# >epoch=543, lrate=0.050, error=0.552
# >epoch=544, lrate=0.050, error=0.551
# >epoch=545, lrate=0.050, error=0.551
# >epoch=546, lrate=0.050, error=0.550
# >epoch=547, lrate=0.050, error=0.549
# >epoch=548, lrate=0.050, error=0.548
# >epoch=549, lrate=0.050, error=0.547
# >epoch=550, lrate=0.050, error=0.546
# >epoch=551, lrate=0.050, error=0.546
# >epoch=552, lrate=0.050, error=0.545
# >epoch=553, lrate=0.050, error=0.544
# >epoch=554, lrate=0.050, error=0.543
# >epoch=555, lrate=0.050, error=0.542
# >epoch=556, lrate=0.050, error=0.541
# >epoch=557, lrate=0.050, error=0.540
# >epoch=558, lrate=0.050, error=0.540
# >epoch=559, lrate=0.050, error=0.539
# >epoch=560, lrate=0.050, error=0.538
# >epoch=561, lrate=0.050, error=0.537
# >epoch=562, lrate=0.050, error=0.536
# >epoch=563, lrate=0.050, error=0.535
# >epoch=564, lrate=0.050, error=0.534
# >epoch=565, lrate=0.050, error=0.534
# >epoch=566, lrate=0.050, error=0.533
# >epoch=567, lrate=0.050, error=0.532
# >epoch=568, lrate=0.050, error=0.531
# >epoch=569, lrate=0.050, error=0.530
# >epoch=570, lrate=0.050, error=0.529
# >epoch=571, lrate=0.050, error=0.528
# >epoch=572, lrate=0.050, error=0.528
# >epoch=573, lrate=0.050, error=0.527
# >epoch=574, lrate=0.050, error=0.526
# >epoch=575, lrate=0.050, error=0.525
# >epoch=576, lrate=0.050, error=0.524
# >epoch=577, lrate=0.050, error=0.523
# >epoch=578, lrate=0.050, error=0.522
# >epoch=579, lrate=0.050, error=0.522
# >epoch=580, lrate=0.050, error=0.521
# >epoch=581, lrate=0.050, error=0.520
# >epoch=582, lrate=0.050, error=0.519
# >epoch=583, lrate=0.050, error=0.518
# >epoch=584, lrate=0.050, error=0.517
# >epoch=585, lrate=0.050, error=0.516
# >epoch=586, lrate=0.050, error=0.515
# >epoch=587, lrate=0.050, error=0.515
# >epoch=588, lrate=0.050, error=0.514
# >epoch=589, lrate=0.050, error=0.513
# >epoch=590, lrate=0.050, error=0.512
# >epoch=591, lrate=0.050, error=0.511
# >epoch=592, lrate=0.050, error=0.510
# >epoch=593, lrate=0.050, error=0.509
# >epoch=594, lrate=0.050, error=0.509
# >epoch=595, lrate=0.050, error=0.508
# >epoch=596, lrate=0.050, error=0.507
# >epoch=597, lrate=0.050, error=0.506
# >epoch=598, lrate=0.050, error=0.505
# >epoch=599, lrate=0.050, error=0.504
# >epoch=600, lrate=0.050, error=0.503
# >epoch=601, lrate=0.050, error=0.503
# >epoch=602, lrate=0.050, error=0.502
# >epoch=603, lrate=0.050, error=0.501
# >epoch=604, lrate=0.050, error=0.500
# >epoch=605, lrate=0.050, error=0.499
# >epoch=606, lrate=0.050, error=0.498
# >epoch=607, lrate=0.050, error=0.497
# >epoch=608, lrate=0.050, error=0.496
# >epoch=609, lrate=0.050, error=0.496
# >epoch=610, lrate=0.050, error=0.495
# >epoch=611, lrate=0.050, error=0.494
# >epoch=612, lrate=0.050, error=0.493
# >epoch=613, lrate=0.050, error=0.492
# >epoch=614, lrate=0.050, error=0.491
# >epoch=615, lrate=0.050, error=0.490
# >epoch=616, lrate=0.050, error=0.489
# >epoch=617, lrate=0.050, error=0.489
# >epoch=618, lrate=0.050, error=0.488
# >epoch=619, lrate=0.050, error=0.487
# >epoch=620, lrate=0.050, error=0.486
# >epoch=621, lrate=0.050, error=0.485
# >epoch=622, lrate=0.050, error=0.484
# >epoch=623, lrate=0.050, error=0.483
# >epoch=624, lrate=0.050, error=0.483
# >epoch=625, lrate=0.050, error=0.482
# >epoch=626, lrate=0.050, error=0.481
# >epoch=627, lrate=0.050, error=0.480
# >epoch=628, lrate=0.050, error=0.479
# >epoch=629, lrate=0.050, error=0.478
# >epoch=630, lrate=0.050, error=0.477
# >epoch=631, lrate=0.050, error=0.476
# >epoch=632, lrate=0.050, error=0.476
# >epoch=633, lrate=0.050, error=0.475
# >epoch=634, lrate=0.050, error=0.474
# >epoch=635, lrate=0.050, error=0.473
# >epoch=636, lrate=0.050, error=0.472
# >epoch=637, lrate=0.050, error=0.471
# >epoch=638, lrate=0.050, error=0.470
# >epoch=639, lrate=0.050, error=0.469
# >epoch=640, lrate=0.050, error=0.469
# >epoch=641, lrate=0.050, error=0.468
# >epoch=642, lrate=0.050, error=0.467
# >epoch=643, lrate=0.050, error=0.466
# >epoch=644, lrate=0.050, error=0.465
# >epoch=645, lrate=0.050, error=0.464
# >epoch=646, lrate=0.050, error=0.463
# >epoch=647, lrate=0.050, error=0.462
# >epoch=648, lrate=0.050, error=0.462
# >epoch=649, lrate=0.050, error=0.461
# >epoch=650, lrate=0.050, error=0.460
# >epoch=651, lrate=0.050, error=0.459
# >epoch=652, lrate=0.050, error=0.458
# >epoch=653, lrate=0.050, error=0.457
# >epoch=654, lrate=0.050, error=0.456
# >epoch=655, lrate=0.050, error=0.456
# >epoch=656, lrate=0.050, error=0.455
# >epoch=657, lrate=0.050, error=0.454
# >epoch=658, lrate=0.050, error=0.453
# >epoch=659, lrate=0.050, error=0.452
# >epoch=660, lrate=0.050, error=0.451
# >epoch=661, lrate=0.050, error=0.450
# >epoch=662, lrate=0.050, error=0.449
# >epoch=663, lrate=0.050, error=0.449
# >epoch=664, lrate=0.050, error=0.448
# >epoch=665, lrate=0.050, error=0.447
# >epoch=666, lrate=0.050, error=0.446
# >epoch=667, lrate=0.050, error=0.445
# >epoch=668, lrate=0.050, error=0.444
# >epoch=669, lrate=0.050, error=0.443
# >epoch=670, lrate=0.050, error=0.443
# >epoch=671, lrate=0.050, error=0.442
# >epoch=672, lrate=0.050, error=0.441
# >epoch=673, lrate=0.050, error=0.440
# >epoch=674, lrate=0.050, error=0.439
# >epoch=675, lrate=0.050, error=0.438
# >epoch=676, lrate=0.050, error=0.437
# >epoch=677, lrate=0.050, error=0.437
# >epoch=678, lrate=0.050, error=0.436
# >epoch=679, lrate=0.050, error=0.435
# >epoch=680, lrate=0.050, error=0.434
# >epoch=681, lrate=0.050, error=0.433
# >epoch=682, lrate=0.050, error=0.432
# >epoch=683, lrate=0.050, error=0.431
# >epoch=684, lrate=0.050, error=0.431
# >epoch=685, lrate=0.050, error=0.430
# >epoch=686, lrate=0.050, error=0.429
# >epoch=687, lrate=0.050, error=0.428
# >epoch=688, lrate=0.050, error=0.427
# >epoch=689, lrate=0.050, error=0.426
# >epoch=690, lrate=0.050, error=0.425
# >epoch=691, lrate=0.050, error=0.425
# >epoch=692, lrate=0.050, error=0.424
# >epoch=693, lrate=0.050, error=0.423
# >epoch=694, lrate=0.050, error=0.422
# >epoch=695, lrate=0.050, error=0.421
# >epoch=696, lrate=0.050, error=0.420
# >epoch=697, lrate=0.050, error=0.419
# >epoch=698, lrate=0.050, error=0.419
# >epoch=699, lrate=0.050, error=0.418
# >epoch=700, lrate=0.050, error=0.417
# >epoch=701, lrate=0.050, error=0.416
# >epoch=702, lrate=0.050, error=0.415
# >epoch=703, lrate=0.050, error=0.414
# >epoch=704, lrate=0.050, error=0.413
# >epoch=705, lrate=0.050, error=0.413
# >epoch=706, lrate=0.050, error=0.412
# >epoch=707, lrate=0.050, error=0.411
# >epoch=708, lrate=0.050, error=0.410
# >epoch=709, lrate=0.050, error=0.409
# >epoch=710, lrate=0.050, error=0.408
# >epoch=711, lrate=0.050, error=0.407
# >epoch=712, lrate=0.050, error=0.407
# >epoch=713, lrate=0.050, error=0.406
# >epoch=714, lrate=0.050, error=0.405
# >epoch=715, lrate=0.050, error=0.404
# >epoch=716, lrate=0.050, error=0.403
# >epoch=717, lrate=0.050, error=0.402
# >epoch=718, lrate=0.050, error=0.402
# >epoch=719, lrate=0.050, error=0.401
# >epoch=720, lrate=0.050, error=0.400
# >epoch=721, lrate=0.050, error=0.399
# >epoch=722, lrate=0.050, error=0.398
# >epoch=723, lrate=0.050, error=0.397
# >epoch=724, lrate=0.050, error=0.397
# >epoch=725, lrate=0.050, error=0.396
# >epoch=726, lrate=0.050, error=0.395
# >epoch=727, lrate=0.050, error=0.394
# >epoch=728, lrate=0.050, error=0.393
# >epoch=729, lrate=0.050, error=0.392
# >epoch=730, lrate=0.050, error=0.392
# >epoch=731, lrate=0.050, error=0.391
# >epoch=732, lrate=0.050, error=0.390
# >epoch=733, lrate=0.050, error=0.389
# >epoch=734, lrate=0.050, error=0.388
# >epoch=735, lrate=0.050, error=0.387
# >epoch=736, lrate=0.050, error=0.387
# >epoch=737, lrate=0.050, error=0.386
# >epoch=738, lrate=0.050, error=0.385
# >epoch=739, lrate=0.050, error=0.384
# >epoch=740, lrate=0.050, error=0.383
# >epoch=741, lrate=0.050, error=0.382
# >epoch=742, lrate=0.050, error=0.382
# >epoch=743, lrate=0.050, error=0.381
# >epoch=744, lrate=0.050, error=0.380
# >epoch=745, lrate=0.050, error=0.379
# >epoch=746, lrate=0.050, error=0.378
# >epoch=747, lrate=0.050, error=0.378
# >epoch=748, lrate=0.050, error=0.377
# >epoch=749, lrate=0.050, error=0.376
# >epoch=750, lrate=0.050, error=0.375
# >epoch=751, lrate=0.050, error=0.374
# >epoch=752, lrate=0.050, error=0.373
# >epoch=753, lrate=0.050, error=0.373
# >epoch=754, lrate=0.050, error=0.372
# >epoch=755, lrate=0.050, error=0.371
# >epoch=756, lrate=0.050, error=0.370
# >epoch=757, lrate=0.050, error=0.369
# >epoch=758, lrate=0.050, error=0.369
# >epoch=759, lrate=0.050, error=0.368
# >epoch=760, lrate=0.050, error=0.367
# >epoch=761, lrate=0.050, error=0.366
# >epoch=762, lrate=0.050, error=0.365
# >epoch=763, lrate=0.050, error=0.365
# >epoch=764, lrate=0.050, error=0.364
# >epoch=765, lrate=0.050, error=0.363
# >epoch=766, lrate=0.050, error=0.362
# >epoch=767, lrate=0.050, error=0.361
# >epoch=768, lrate=0.050, error=0.361
# >epoch=769, lrate=0.050, error=0.360
# >epoch=770, lrate=0.050, error=0.359
# >epoch=771, lrate=0.050, error=0.358
# >epoch=772, lrate=0.050, error=0.357
# >epoch=773, lrate=0.050, error=0.357
# >epoch=774, lrate=0.050, error=0.356
# >epoch=775, lrate=0.050, error=0.355
# >epoch=776, lrate=0.050, error=0.354
# >epoch=777, lrate=0.050, error=0.353
# >epoch=778, lrate=0.050, error=0.353
# >epoch=779, lrate=0.050, error=0.352
# >epoch=780, lrate=0.050, error=0.351
# >epoch=781, lrate=0.050, error=0.350
# >epoch=782, lrate=0.050, error=0.349
# >epoch=783, lrate=0.050, error=0.349
# >epoch=784, lrate=0.050, error=0.348
# >epoch=785, lrate=0.050, error=0.347
# >epoch=786, lrate=0.050, error=0.346
# >epoch=787, lrate=0.050, error=0.346
# >epoch=788, lrate=0.050, error=0.345
# >epoch=789, lrate=0.050, error=0.344
# >epoch=790, lrate=0.050, error=0.343
# >epoch=791, lrate=0.050, error=0.342
# >epoch=792, lrate=0.050, error=0.342
# >epoch=793, lrate=0.050, error=0.341
# >epoch=794, lrate=0.050, error=0.340
# >epoch=795, lrate=0.050, error=0.339
# >epoch=796, lrate=0.050, error=0.339
# >epoch=797, lrate=0.050, error=0.338
# >epoch=798, lrate=0.050, error=0.337
# >epoch=799, lrate=0.050, error=0.336
# >epoch=800, lrate=0.050, error=0.336
# >epoch=801, lrate=0.050, error=0.335
# >epoch=802, lrate=0.050, error=0.334
# >epoch=803, lrate=0.050, error=0.333
# >epoch=804, lrate=0.050, error=0.332
# >epoch=805, lrate=0.050, error=0.332
# >epoch=806, lrate=0.050, error=0.331
# >epoch=807, lrate=0.050, error=0.330
# >epoch=808, lrate=0.050, error=0.329
# >epoch=809, lrate=0.050, error=0.329
# >epoch=810, lrate=0.050, error=0.328
# >epoch=811, lrate=0.050, error=0.327
# >epoch=812, lrate=0.050, error=0.326
# >epoch=813, lrate=0.050, error=0.326
# >epoch=814, lrate=0.050, error=0.325
# >epoch=815, lrate=0.050, error=0.324
# >epoch=816, lrate=0.050, error=0.323
# >epoch=817, lrate=0.050, error=0.323
# >epoch=818, lrate=0.050, error=0.322
# >epoch=819, lrate=0.050, error=0.321
# >epoch=820, lrate=0.050, error=0.320
# >epoch=821, lrate=0.050, error=0.320
# >epoch=822, lrate=0.050, error=0.319
# >epoch=823, lrate=0.050, error=0.318
# >epoch=824, lrate=0.050, error=0.317
# >epoch=825, lrate=0.050, error=0.317
# >epoch=826, lrate=0.050, error=0.316
# >epoch=827, lrate=0.050, error=0.315
# >epoch=828, lrate=0.050, error=0.315
# >epoch=829, lrate=0.050, error=0.314
# >epoch=830, lrate=0.050, error=0.313
# >epoch=831, lrate=0.050, error=0.312
# >epoch=832, lrate=0.050, error=0.312
# >epoch=833, lrate=0.050, error=0.311
# >epoch=834, lrate=0.050, error=0.310
# >epoch=835, lrate=0.050, error=0.309
# >epoch=836, lrate=0.050, error=0.309
# >epoch=837, lrate=0.050, error=0.308
# >epoch=838, lrate=0.050, error=0.307
# >epoch=839, lrate=0.050, error=0.307
# >epoch=840, lrate=0.050, error=0.306
# >epoch=841, lrate=0.050, error=0.305
# >epoch=842, lrate=0.050, error=0.304
# >epoch=843, lrate=0.050, error=0.304
# >epoch=844, lrate=0.050, error=0.303
# >epoch=845, lrate=0.050, error=0.302
# >epoch=846, lrate=0.050, error=0.302
# >epoch=847, lrate=0.050, error=0.301
# >epoch=848, lrate=0.050, error=0.300
# >epoch=849, lrate=0.050, error=0.299
# >epoch=850, lrate=0.050, error=0.299
# >epoch=851, lrate=0.050, error=0.298
# >epoch=852, lrate=0.050, error=0.297
# >epoch=853, lrate=0.050, error=0.297
# >epoch=854, lrate=0.050, error=0.296
# >epoch=855, lrate=0.050, error=0.295
# >epoch=856, lrate=0.050, error=0.295
# >epoch=857, lrate=0.050, error=0.294
# >epoch=858, lrate=0.050, error=0.293
# >epoch=859, lrate=0.050, error=0.292
# >epoch=860, lrate=0.050, error=0.292
# >epoch=861, lrate=0.050, error=0.291
# >epoch=862, lrate=0.050, error=0.290
# >epoch=863, lrate=0.050, error=0.290
# >epoch=864, lrate=0.050, error=0.289
# >epoch=865, lrate=0.050, error=0.288
# >epoch=866, lrate=0.050, error=0.288
# >epoch=867, lrate=0.050, error=0.287
# >epoch=868, lrate=0.050, error=0.286
# >epoch=869, lrate=0.050, error=0.286
# >epoch=870, lrate=0.050, error=0.285
# >epoch=871, lrate=0.050, error=0.284
# >epoch=872, lrate=0.050, error=0.284
# >epoch=873, lrate=0.050, error=0.283
# >epoch=874, lrate=0.050, error=0.282
# >epoch=875, lrate=0.050, error=0.282
# >epoch=876, lrate=0.050, error=0.281
# >epoch=877, lrate=0.050, error=0.280
# >epoch=878, lrate=0.050, error=0.280
# >epoch=879, lrate=0.050, error=0.279
# >epoch=880, lrate=0.050, error=0.278
# >epoch=881, lrate=0.050, error=0.278
# >epoch=882, lrate=0.050, error=0.277
# >epoch=883, lrate=0.050, error=0.276
# >epoch=884, lrate=0.050, error=0.276
# >epoch=885, lrate=0.050, error=0.275
# >epoch=886, lrate=0.050, error=0.274
# >epoch=887, lrate=0.050, error=0.274
# >epoch=888, lrate=0.050, error=0.273
# >epoch=889, lrate=0.050, error=0.272
# >epoch=890, lrate=0.050, error=0.272
# >epoch=891, lrate=0.050, error=0.271
# >epoch=892, lrate=0.050, error=0.270
# >epoch=893, lrate=0.050, error=0.270
# >epoch=894, lrate=0.050, error=0.269
# >epoch=895, lrate=0.050, error=0.268
# >epoch=896, lrate=0.050, error=0.268
# >epoch=897, lrate=0.050, error=0.267
# >epoch=898, lrate=0.050, error=0.266
# >epoch=899, lrate=0.050, error=0.266
# >epoch=900, lrate=0.050, error=0.265
# >epoch=901, lrate=0.050, error=0.265
# >epoch=902, lrate=0.050, error=0.264
# >epoch=903, lrate=0.050, error=0.263
# >epoch=904, lrate=0.050, error=0.263
# >epoch=905, lrate=0.050, error=0.262
# >epoch=906, lrate=0.050, error=0.261
# >epoch=907, lrate=0.050, error=0.261
# >epoch=908, lrate=0.050, error=0.260
# >epoch=909, lrate=0.050, error=0.259
# >epoch=910, lrate=0.050, error=0.259
# >epoch=911, lrate=0.050, error=0.258
# >epoch=912, lrate=0.050, error=0.258
# >epoch=913, lrate=0.050, error=0.257
# >epoch=914, lrate=0.050, error=0.256
# >epoch=915, lrate=0.050, error=0.256
# >epoch=916, lrate=0.050, error=0.255
# >epoch=917, lrate=0.050, error=0.254
# >epoch=918, lrate=0.050, error=0.254
# >epoch=919, lrate=0.050, error=0.253
# >epoch=920, lrate=0.050, error=0.253
# >epoch=921, lrate=0.050, error=0.252
# >epoch=922, lrate=0.050, error=0.251
# >epoch=923, lrate=0.050, error=0.251
# >epoch=924, lrate=0.050, error=0.250
# >epoch=925, lrate=0.050, error=0.250
# >epoch=926, lrate=0.050, error=0.249
# >epoch=927, lrate=0.050, error=0.248
# >epoch=928, lrate=0.050, error=0.248
# >epoch=929, lrate=0.050, error=0.247
# >epoch=930, lrate=0.050, error=0.247
# >epoch=931, lrate=0.050, error=0.246
# >epoch=932, lrate=0.050, error=0.245
# >epoch=933, lrate=0.050, error=0.245
# >epoch=934, lrate=0.050, error=0.244
# >epoch=935, lrate=0.050, error=0.244
# >epoch=936, lrate=0.050, error=0.243
# >epoch=937, lrate=0.050, error=0.242
# >epoch=938, lrate=0.050, error=0.242
# >epoch=939, lrate=0.050, error=0.241
# >epoch=940, lrate=0.050, error=0.241
# >epoch=941, lrate=0.050, error=0.240
# >epoch=942, lrate=0.050, error=0.240
# >epoch=943, lrate=0.050, error=0.239
# >epoch=944, lrate=0.050, error=0.238
# >epoch=945, lrate=0.050, error=0.238
# >epoch=946, lrate=0.050, error=0.237
# >epoch=947, lrate=0.050, error=0.237
# >epoch=948, lrate=0.050, error=0.236
# >epoch=949, lrate=0.050, error=0.235
# >epoch=950, lrate=0.050, error=0.235
# >epoch=951, lrate=0.050, error=0.234
# >epoch=952, lrate=0.050, error=0.234
# >epoch=953, lrate=0.050, error=0.233
# >epoch=954, lrate=0.050, error=0.233
# >epoch=955, lrate=0.050, error=0.232
# >epoch=956, lrate=0.050, error=0.232
# >epoch=957, lrate=0.050, error=0.231
# >epoch=958, lrate=0.050, error=0.230
# >epoch=959, lrate=0.050, error=0.230
# >epoch=960, lrate=0.050, error=0.229
# >epoch=961, lrate=0.050, error=0.229
# >epoch=962, lrate=0.050, error=0.228
# >epoch=963, lrate=0.050, error=0.228
# >epoch=964, lrate=0.050, error=0.227
# >epoch=965, lrate=0.050, error=0.227
# >epoch=966, lrate=0.050, error=0.226
# >epoch=967, lrate=0.050, error=0.225
# >epoch=968, lrate=0.050, error=0.225
# >epoch=969, lrate=0.050, error=0.224
# >epoch=970, lrate=0.050, error=0.224
# >epoch=971, lrate=0.050, error=0.223
# >epoch=972, lrate=0.050, error=0.223
# >epoch=973, lrate=0.050, error=0.222
# >epoch=974, lrate=0.050, error=0.222
# >epoch=975, lrate=0.050, error=0.221
# >epoch=976, lrate=0.050, error=0.221
# >epoch=977, lrate=0.050, error=0.220
# >epoch=978, lrate=0.050, error=0.219
# >epoch=979, lrate=0.050, error=0.219
# >epoch=980, lrate=0.050, error=0.218
# >epoch=981, lrate=0.050, error=0.218
# >epoch=982, lrate=0.050, error=0.217
# >epoch=983, lrate=0.050, error=0.217
# >epoch=984, lrate=0.050, error=0.216
# >epoch=985, lrate=0.050, error=0.216
# >epoch=986, lrate=0.050, error=0.215
# >epoch=987, lrate=0.050, error=0.215
# >epoch=988, lrate=0.050, error=0.214
# >epoch=989, lrate=0.050, error=0.214
# >epoch=990, lrate=0.050, error=0.213
# >epoch=991, lrate=0.050, error=0.213
# >epoch=992, lrate=0.050, error=0.212
# >epoch=993, lrate=0.050, error=0.212
# >epoch=994, lrate=0.050, error=0.211
# >epoch=995, lrate=0.050, error=0.211
# >epoch=996, lrate=0.050, error=0.210
# >epoch=997, lrate=0.050, error=0.210
# >epoch=998, lrate=0.050, error=0.209
# >epoch=999, lrate=0.050, error=0.209
# >epoch=1000, lrate=0.050, error=0.208
# >epoch=1001, lrate=0.050, error=0.208
# >epoch=1002, lrate=0.050, error=0.207
# >epoch=1003, lrate=0.050, error=0.207
# >epoch=1004, lrate=0.050, error=0.206
# >epoch=1005, lrate=0.050, error=0.206
# >epoch=1006, lrate=0.050, error=0.205
# >epoch=1007, lrate=0.050, error=0.205
# >epoch=1008, lrate=0.050, error=0.204
# >epoch=1009, lrate=0.050, error=0.204
# >epoch=1010, lrate=0.050, error=0.203
# >epoch=1011, lrate=0.050, error=0.203
# >epoch=1012, lrate=0.050, error=0.202
# >epoch=1013, lrate=0.050, error=0.202
# >epoch=1014, lrate=0.050, error=0.201
# >epoch=1015, lrate=0.050, error=0.201
# >epoch=1016, lrate=0.050, error=0.200
# >epoch=1017, lrate=0.050, error=0.200
# >epoch=1018, lrate=0.050, error=0.199
# >epoch=1019, lrate=0.050, error=0.199
# >epoch=1020, lrate=0.050, error=0.198
# >epoch=1021, lrate=0.050, error=0.198
# >epoch=1022, lrate=0.050, error=0.197
# >epoch=1023, lrate=0.050, error=0.197
# >epoch=1024, lrate=0.050, error=0.196
# >epoch=1025, lrate=0.050, error=0.196
# >epoch=1026, lrate=0.050, error=0.195
# >epoch=1027, lrate=0.050, error=0.195
# >epoch=1028, lrate=0.050, error=0.194
# >epoch=1029, lrate=0.050, error=0.194
# >epoch=1030, lrate=0.050, error=0.193
# >epoch=1031, lrate=0.050, error=0.193
# >epoch=1032, lrate=0.050, error=0.193
# >epoch=1033, lrate=0.050, error=0.192
# >epoch=1034, lrate=0.050, error=0.192
# >epoch=1035, lrate=0.050, error=0.191
# >epoch=1036, lrate=0.050, error=0.191
# >epoch=1037, lrate=0.050, error=0.190
# >epoch=1038, lrate=0.050, error=0.190
# >epoch=1039, lrate=0.050, error=0.189
# >epoch=1040, lrate=0.050, error=0.189
# >epoch=1041, lrate=0.050, error=0.188
# >epoch=1042, lrate=0.050, error=0.188
# >epoch=1043, lrate=0.050, error=0.187
# >epoch=1044, lrate=0.050, error=0.187
# >epoch=1045, lrate=0.050, error=0.187
# >epoch=1046, lrate=0.050, error=0.186
# >epoch=1047, lrate=0.050, error=0.186
# >epoch=1048, lrate=0.050, error=0.185
# >epoch=1049, lrate=0.050, error=0.185
# >epoch=1050, lrate=0.050, error=0.184
# >epoch=1051, lrate=0.050, error=0.184
# >epoch=1052, lrate=0.050, error=0.183
# >epoch=1053, lrate=0.050, error=0.183
# >epoch=1054, lrate=0.050, error=0.183
# >epoch=1055, lrate=0.050, error=0.182
# >epoch=1056, lrate=0.050, error=0.182
# >epoch=1057, lrate=0.050, error=0.181
# >epoch=1058, lrate=0.050, error=0.181
# >epoch=1059, lrate=0.050, error=0.180
# >epoch=1060, lrate=0.050, error=0.180
# >epoch=1061, lrate=0.050, error=0.180
# >epoch=1062, lrate=0.050, error=0.179
# >epoch=1063, lrate=0.050, error=0.179
# >epoch=1064, lrate=0.050, error=0.178
# >epoch=1065, lrate=0.050, error=0.178
# >epoch=1066, lrate=0.050, error=0.177
# >epoch=1067, lrate=0.050, error=0.177
# >epoch=1068, lrate=0.050, error=0.177
# >epoch=1069, lrate=0.050, error=0.176
# >epoch=1070, lrate=0.050, error=0.176
# >epoch=1071, lrate=0.050, error=0.175
# >epoch=1072, lrate=0.050, error=0.175
# >epoch=1073, lrate=0.050, error=0.174
# >epoch=1074, lrate=0.050, error=0.174
# >epoch=1075, lrate=0.050, error=0.174
# >epoch=1076, lrate=0.050, error=0.173
# >epoch=1077, lrate=0.050, error=0.173
# >epoch=1078, lrate=0.050, error=0.172
# >epoch=1079, lrate=0.050, error=0.172
# >epoch=1080, lrate=0.050, error=0.172
# >epoch=1081, lrate=0.050, error=0.171
# >epoch=1082, lrate=0.050, error=0.171
# >epoch=1083, lrate=0.050, error=0.170
# >epoch=1084, lrate=0.050, error=0.170
# >epoch=1085, lrate=0.050, error=0.170
# >epoch=1086, lrate=0.050, error=0.169
# >epoch=1087, lrate=0.050, error=0.169
# >epoch=1088, lrate=0.050, error=0.168
# >epoch=1089, lrate=0.050, error=0.168
# >epoch=1090, lrate=0.050, error=0.168
# >epoch=1091, lrate=0.050, error=0.167
# >epoch=1092, lrate=0.050, error=0.167
# >epoch=1093, lrate=0.050, error=0.166
# >epoch=1094, lrate=0.050, error=0.166
# >epoch=1095, lrate=0.050, error=0.166
# >epoch=1096, lrate=0.050, error=0.165
# >epoch=1097, lrate=0.050, error=0.165
# >epoch=1098, lrate=0.050, error=0.164
# >epoch=1099, lrate=0.050, error=0.164
# >epoch=1100, lrate=0.050, error=0.164
# >epoch=1101, lrate=0.050, error=0.163
# >epoch=1102, lrate=0.050, error=0.163
# >epoch=1103, lrate=0.050, error=0.162
# >epoch=1104, lrate=0.050, error=0.162
# >epoch=1105, lrate=0.050, error=0.162
# >epoch=1106, lrate=0.050, error=0.161
# >epoch=1107, lrate=0.050, error=0.161
# >epoch=1108, lrate=0.050, error=0.161
# >epoch=1109, lrate=0.050, error=0.160
# >epoch=1110, lrate=0.050, error=0.160
# >epoch=1111, lrate=0.050, error=0.159
# >epoch=1112, lrate=0.050, error=0.159
# >epoch=1113, lrate=0.050, error=0.159
# >epoch=1114, lrate=0.050, error=0.158
# >epoch=1115, lrate=0.050, error=0.158
# >epoch=1116, lrate=0.050, error=0.158
# >epoch=1117, lrate=0.050, error=0.157
# >epoch=1118, lrate=0.050, error=0.157
# >epoch=1119, lrate=0.050, error=0.156
# >epoch=1120, lrate=0.050, error=0.156
# >epoch=1121, lrate=0.050, error=0.156
# >epoch=1122, lrate=0.050, error=0.155
# >epoch=1123, lrate=0.050, error=0.155
# >epoch=1124, lrate=0.050, error=0.155
# >epoch=1125, lrate=0.050, error=0.154
# >epoch=1126, lrate=0.050, error=0.154
# >epoch=1127, lrate=0.050, error=0.154
# >epoch=1128, lrate=0.050, error=0.153
# >epoch=1129, lrate=0.050, error=0.153
# >epoch=1130, lrate=0.050, error=0.152
# >epoch=1131, lrate=0.050, error=0.152
# >epoch=1132, lrate=0.050, error=0.152
# >epoch=1133, lrate=0.050, error=0.151
# >epoch=1134, lrate=0.050, error=0.151
# >epoch=1135, lrate=0.050, error=0.151
# >epoch=1136, lrate=0.050, error=0.150
# >epoch=1137, lrate=0.050, error=0.150
# >epoch=1138, lrate=0.050, error=0.150
# >epoch=1139, lrate=0.050, error=0.149
# >epoch=1140, lrate=0.050, error=0.149
# >epoch=1141, lrate=0.050, error=0.149
# >epoch=1142, lrate=0.050, error=0.148
# >epoch=1143, lrate=0.050, error=0.148
# >epoch=1144, lrate=0.050, error=0.148
# >epoch=1145, lrate=0.050, error=0.147
# >epoch=1146, lrate=0.050, error=0.147
# >epoch=1147, lrate=0.050, error=0.146
# >epoch=1148, lrate=0.050, error=0.146
# >epoch=1149, lrate=0.050, error=0.146
# >epoch=1150, lrate=0.050, error=0.145
# >epoch=1151, lrate=0.050, error=0.145
# >epoch=1152, lrate=0.050, error=0.145
# >epoch=1153, lrate=0.050, error=0.144
# >epoch=1154, lrate=0.050, error=0.144
# >epoch=1155, lrate=0.050, error=0.144
# >epoch=1156, lrate=0.050, error=0.143
# >epoch=1157, lrate=0.050, error=0.143
# >epoch=1158, lrate=0.050, error=0.143
# >epoch=1159, lrate=0.050, error=0.142
# >epoch=1160, lrate=0.050, error=0.142
# >epoch=1161, lrate=0.050, error=0.142
# >epoch=1162, lrate=0.050, error=0.141
# >epoch=1163, lrate=0.050, error=0.141
# >epoch=1164, lrate=0.050, error=0.141
# >epoch=1165, lrate=0.050, error=0.140
# >epoch=1166, lrate=0.050, error=0.140
# >epoch=1167, lrate=0.050, error=0.140
# >epoch=1168, lrate=0.050, error=0.140
# >epoch=1169, lrate=0.050, error=0.139
# >epoch=1170, lrate=0.050, error=0.139
# >epoch=1171, lrate=0.050, error=0.139
# >epoch=1172, lrate=0.050, error=0.138
# >epoch=1173, lrate=0.050, error=0.138
# >epoch=1174, lrate=0.050, error=0.138
# >epoch=1175, lrate=0.050, error=0.137
# >epoch=1176, lrate=0.050, error=0.137
# >epoch=1177, lrate=0.050, error=0.137
# >epoch=1178, lrate=0.050, error=0.136
# >epoch=1179, lrate=0.050, error=0.136
# >epoch=1180, lrate=0.050, error=0.136
# >epoch=1181, lrate=0.050, error=0.135
# >epoch=1182, lrate=0.050, error=0.135
# >epoch=1183, lrate=0.050, error=0.135
# >epoch=1184, lrate=0.050, error=0.134
# >epoch=1185, lrate=0.050, error=0.134
# >epoch=1186, lrate=0.050, error=0.134
# >epoch=1187, lrate=0.050, error=0.134
# >epoch=1188, lrate=0.050, error=0.133
# >epoch=1189, lrate=0.050, error=0.133
# >epoch=1190, lrate=0.050, error=0.133
# >epoch=1191, lrate=0.050, error=0.132
# >epoch=1192, lrate=0.050, error=0.132
# >epoch=1193, lrate=0.050, error=0.132
# >epoch=1194, lrate=0.050, error=0.131
# >epoch=1195, lrate=0.050, error=0.131
# >epoch=1196, lrate=0.050, error=0.131
# >epoch=1197, lrate=0.050, error=0.131
# >epoch=1198, lrate=0.050, error=0.130
# >epoch=1199, lrate=0.050, error=0.130
# >epoch=1200, lrate=0.050, error=0.130
# >epoch=1201, lrate=0.050, error=0.129
# >epoch=1202, lrate=0.050, error=0.129
# >epoch=1203, lrate=0.050, error=0.129
# >epoch=1204, lrate=0.050, error=0.128
# >epoch=1205, lrate=0.050, error=0.128
# >epoch=1206, lrate=0.050, error=0.128
# >epoch=1207, lrate=0.050, error=0.128
# >epoch=1208, lrate=0.050, error=0.127
# >epoch=1209, lrate=0.050, error=0.127
# >epoch=1210, lrate=0.050, error=0.127
# >epoch=1211, lrate=0.050, error=0.126
# >epoch=1212, lrate=0.050, error=0.126
# >epoch=1213, lrate=0.050, error=0.126
# >epoch=1214, lrate=0.050, error=0.126
# >epoch=1215, lrate=0.050, error=0.125
# >epoch=1216, lrate=0.050, error=0.125
# >epoch=1217, lrate=0.050, error=0.125
# >epoch=1218, lrate=0.050, error=0.124
# >epoch=1219, lrate=0.050, error=0.124
# >epoch=1220, lrate=0.050, error=0.124
# >epoch=1221, lrate=0.050, error=0.124
# >epoch=1222, lrate=0.050, error=0.123
# >epoch=1223, lrate=0.050, error=0.123
# >epoch=1224, lrate=0.050, error=0.123
# >epoch=1225, lrate=0.050, error=0.123
# >epoch=1226, lrate=0.050, error=0.122
# >epoch=1227, lrate=0.050, error=0.122
# >epoch=1228, lrate=0.050, error=0.122
# >epoch=1229, lrate=0.050, error=0.121
# >epoch=1230, lrate=0.050, error=0.121
# >epoch=1231, lrate=0.050, error=0.121
# >epoch=1232, lrate=0.050, error=0.121
# >epoch=1233, lrate=0.050, error=0.120
# >epoch=1234, lrate=0.050, error=0.120
# >epoch=1235, lrate=0.050, error=0.120
# >epoch=1236, lrate=0.050, error=0.120
# >epoch=1237, lrate=0.050, error=0.119
# >epoch=1238, lrate=0.050, error=0.119
# >epoch=1239, lrate=0.050, error=0.119
# >epoch=1240, lrate=0.050, error=0.118
# >epoch=1241, lrate=0.050, error=0.118
# >epoch=1242, lrate=0.050, error=0.118
# >epoch=1243, lrate=0.050, error=0.118
# >epoch=1244, lrate=0.050, error=0.117
# >epoch=1245, lrate=0.050, error=0.117
# >epoch=1246, lrate=0.050, error=0.117
# >epoch=1247, lrate=0.050, error=0.117
# >epoch=1248, lrate=0.050, error=0.116
# >epoch=1249, lrate=0.050, error=0.116
# >epoch=1250, lrate=0.050, error=0.116
# >epoch=1251, lrate=0.050, error=0.116
# >epoch=1252, lrate=0.050, error=0.115
# >epoch=1253, lrate=0.050, error=0.115
# >epoch=1254, lrate=0.050, error=0.115
# >epoch=1255, lrate=0.050, error=0.115
# >epoch=1256, lrate=0.050, error=0.114
# >epoch=1257, lrate=0.050, error=0.114
# >epoch=1258, lrate=0.050, error=0.114
# >epoch=1259, lrate=0.050, error=0.114
# >epoch=1260, lrate=0.050, error=0.113
# >epoch=1261, lrate=0.050, error=0.113
# >epoch=1262, lrate=0.050, error=0.113
# >epoch=1263, lrate=0.050, error=0.113
# >epoch=1264, lrate=0.050, error=0.112
# >epoch=1265, lrate=0.050, error=0.112
# >epoch=1266, lrate=0.050, error=0.112
# >epoch=1267, lrate=0.050, error=0.112
# >epoch=1268, lrate=0.050, error=0.111
# >epoch=1269, lrate=0.050, error=0.111
# >epoch=1270, lrate=0.050, error=0.111
# >epoch=1271, lrate=0.050, error=0.111
# >epoch=1272, lrate=0.050, error=0.110
# >epoch=1273, lrate=0.050, error=0.110
# >epoch=1274, lrate=0.050, error=0.110
# >epoch=1275, lrate=0.050, error=0.110
# >epoch=1276, lrate=0.050, error=0.109
# >epoch=1277, lrate=0.050, error=0.109
# >epoch=1278, lrate=0.050, error=0.109
# >epoch=1279, lrate=0.050, error=0.109
# >epoch=1280, lrate=0.050, error=0.108
# >epoch=1281, lrate=0.050, error=0.108
# >epoch=1282, lrate=0.050, error=0.108
# >epoch=1283, lrate=0.050, error=0.108
# >epoch=1284, lrate=0.050, error=0.108
# >epoch=1285, lrate=0.050, error=0.107
# >epoch=1286, lrate=0.050, error=0.107
# >epoch=1287, lrate=0.050, error=0.107
# >epoch=1288, lrate=0.050, error=0.107
# >epoch=1289, lrate=0.050, error=0.106
# >epoch=1290, lrate=0.050, error=0.106
# >epoch=1291, lrate=0.050, error=0.106
# ...
# >epoch=3139, lrate=0.050, error=0.018
# >epoch=3140, lrate=0.050, error=0.018
# >epoch=3141, lrate=0.050, error=0.018
# >epoch=3142, lrate=0.050, error=0.018
# >epoch=3143, lrate=0.050, error=0.018
# >epoch=3144, lrate=0.050, error=0.018
# >epoch=3145, lrate=0.050, error=0.018
# >epoch=3146, lrate=0.050, error=0.017
# >epoch=3147, lrate=0.050, error=0.017
# >epoch=3148, lrate=0.050, error=0.017
# >epoch=3149, lrate=0.050, error=0.017
# >epoch=3150, lrate=0.050, error=0.017
# >epoch=3151, lrate=0.050, error=0.017
# >epoch=3152, lrate=0.050, error=0.017
# >epoch=3153, lrate=0.050, error=0.017
# >epoch=3154, lrate=0.050, error=0.017
# >epoch=3155, lrate=0.050, error=0.017
# >epoch=3156, lrate=0.050, error=0.017
# >epoch=3157, lrate=0.050, error=0.017
# >epoch=3158, lrate=0.050, error=0.017
# >epoch=3159, lrate=0.050, error=0.017
# >epoch=3160, lrate=0.050, error=0.017
# >epoch=3161, lrate=0.050, error=0.017
# >epoch=3162, lrate=0.050, error=0.017
# >epoch=3163, lrate=0.050, error=0.017
# >epoch=3164, lrate=0.050, error=0.017
# >epoch=3165, lrate=0.050, error=0.017
# >epoch=3166, lrate=0.050, error=0.017
# >epoch=3167, lrate=0.050, error=0.017
# >epoch=3168, lrate=0.050, error=0.017
# >epoch=3169, lrate=0.050, error=0.017
# >epoch=3170, lrate=0.050, error=0.017
# >epoch=3171, lrate=0.050, error=0.017
# >epoch=3172, lrate=0.050, error=0.017
# >epoch=3173, lrate=0.050, error=0.017
# >epoch=3174, lrate=0.050, error=0.017
# >epoch=3175, lrate=0.050, error=0.017
# >epoch=3176, lrate=0.050, error=0.017
# >epoch=3177, lrate=0.050, error=0.017
# >epoch=3178, lrate=0.050, error=0.017
# >epoch=3179, lrate=0.050, error=0.017
# >epoch=3180, lrate=0.050, error=0.017
# >epoch=3181, lrate=0.050, error=0.017
# >epoch=3182, lrate=0.050, error=0.017
# >epoch=3183, lrate=0.050, error=0.017
# >epoch=3184, lrate=0.050, error=0.017
# >epoch=3185, lrate=0.050, error=0.017
# >epoch=3186, lrate=0.050, error=0.017
# >epoch=3187, lrate=0.050, error=0.017
# >epoch=3188, lrate=0.050, error=0.017
# >epoch=3189, lrate=0.050, error=0.017
# >epoch=3190, lrate=0.050, error=0.017
# >epoch=3191, lrate=0.050, error=0.017
# >epoch=3192, lrate=0.050, error=0.017
# >epoch=3193, lrate=0.050, error=0.017
# >epoch=3194, lrate=0.050, error=0.017
# >epoch=3195, lrate=0.050, error=0.017
# >epoch=3196, lrate=0.050, error=0.017
# >epoch=3197, lrate=0.050, error=0.017
# >epoch=3198, lrate=0.050, error=0.017
# >epoch=3199, lrate=0.050, error=0.017
# >epoch=3200, lrate=0.050, error=0.017
# >epoch=3201, lrate=0.050, error=0.017
# >epoch=3202, lrate=0.050, error=0.017
# >epoch=3203, lrate=0.050, error=0.017
# >epoch=3204, lrate=0.050, error=0.017
# >epoch=3205, lrate=0.050, error=0.017
# >epoch=3206, lrate=0.050, error=0.017
# >epoch=3207, lrate=0.050, error=0.017
# >epoch=3208, lrate=0.050, error=0.017
# >epoch=3209, lrate=0.050, error=0.017
# >epoch=3210, lrate=0.050, error=0.017
# >epoch=3211, lrate=0.050, error=0.017
# >epoch=3212, lrate=0.050, error=0.017
# >epoch=3213, lrate=0.050, error=0.017
# >epoch=3214, lrate=0.050, error=0.017
# >epoch=3215, lrate=0.050, error=0.017
# >epoch=3216, lrate=0.050, error=0.017
# >epoch=3217, lrate=0.050, error=0.017
# >epoch=3218, lrate=0.050, error=0.017
# >epoch=3219, lrate=0.050, error=0.017
# >epoch=3220, lrate=0.050, error=0.017
# >epoch=3221, lrate=0.050, error=0.017
# >epoch=3222, lrate=0.050, error=0.017
# >epoch=3223, lrate=0.050, error=0.017
# >epoch=3224, lrate=0.050, error=0.017
# >epoch=3225, lrate=0.050, error=0.017
# >epoch=3226, lrate=0.050, error=0.017
# >epoch=3227, lrate=0.050, error=0.017
# >epoch=3228, lrate=0.050, error=0.017
# >epoch=3229, lrate=0.050, error=0.017
# >epoch=3230, lrate=0.050, error=0.017
# >epoch=3231, lrate=0.050, error=0.017
# >epoch=3232, lrate=0.050, error=0.017
# >epoch=3233, lrate=0.050, error=0.017
# >epoch=3234, lrate=0.050, error=0.017
# >epoch=3235, lrate=0.050, error=0.017
# >epoch=3236, lrate=0.050, error=0.017
# >epoch=3237, lrate=0.050, error=0.017
# >epoch=3238, lrate=0.050, error=0.017
# >epoch=3239, lrate=0.050, error=0.017
# >epoch=3240, lrate=0.050, error=0.017
# >epoch=3241, lrate=0.050, error=0.017
# >epoch=3242, lrate=0.050, error=0.017
# >epoch=3243, lrate=0.050, error=0.017
# >epoch=3244, lrate=0.050, error=0.017
# >epoch=3245, lrate=0.050, error=0.017
# >epoch=3246, lrate=0.050, error=0.017
# >epoch=3247, lrate=0.050, error=0.017
# >epoch=3248, lrate=0.050, error=0.017
# >epoch=3249, lrate=0.050, error=0.017
# >epoch=3250, lrate=0.050, error=0.017
# >epoch=3251, lrate=0.050, error=0.017
# >epoch=3252, lrate=0.050, error=0.017
# >epoch=3253, lrate=0.050, error=0.017
# >epoch=3254, lrate=0.050, error=0.017
# >epoch=3255, lrate=0.050, error=0.017
# >epoch=3256, lrate=0.050, error=0.017
# >epoch=3257, lrate=0.050, error=0.017
# >epoch=3258, lrate=0.050, error=0.017
# >epoch=3259, lrate=0.050, error=0.017
# >epoch=3260, lrate=0.050, error=0.017
# >epoch=3261, lrate=0.050, error=0.017
# >epoch=3262, lrate=0.050, error=0.017
# >epoch=3263, lrate=0.050, error=0.017
# >epoch=3264, lrate=0.050, error=0.017
# >epoch=3265, lrate=0.050, error=0.017
# >epoch=3266, lrate=0.050, error=0.017
# >epoch=3267, lrate=0.050, error=0.017
# >epoch=3268, lrate=0.050, error=0.017
# >epoch=3269, lrate=0.050, error=0.017
# >epoch=3270, lrate=0.050, error=0.017
# >epoch=3271, lrate=0.050, error=0.017
# >epoch=3272, lrate=0.050, error=0.017
# >epoch=3273, lrate=0.050, error=0.017
# >epoch=3274, lrate=0.050, error=0.017
# >epoch=3275, lrate=0.050, error=0.017
# >epoch=3276, lrate=0.050, error=0.017
# >epoch=3277, lrate=0.050, error=0.017
# >epoch=3278, lrate=0.050, error=0.017
# >epoch=3279, lrate=0.050, error=0.017
# >epoch=3280, lrate=0.050, error=0.017
# >epoch=3281, lrate=0.050, error=0.017
# >epoch=3282, lrate=0.050, error=0.017
# >epoch=3283, lrate=0.050, error=0.017
# >epoch=3284, lrate=0.050, error=0.017
# >epoch=3285, lrate=0.050, error=0.017
# >epoch=3286, lrate=0.050, error=0.017
# >epoch=3287, lrate=0.050, error=0.017
# >epoch=3288, lrate=0.050, error=0.017
# >epoch=3289, lrate=0.050, error=0.017
# >epoch=3290, lrate=0.050, error=0.017
# >epoch=3291, lrate=0.050, error=0.017
# >epoch=3292, lrate=0.050, error=0.017
# >epoch=3293, lrate=0.050, error=0.017
# >epoch=3294, lrate=0.050, error=0.017
# >epoch=3295, lrate=0.050, error=0.017
# >epoch=3296, lrate=0.050, error=0.017
# >epoch=3297, lrate=0.050, error=0.017
# >epoch=3298, lrate=0.050, error=0.017
# >epoch=3299, lrate=0.050, error=0.017
# >epoch=3300, lrate=0.050, error=0.017
# >epoch=3301, lrate=0.050, error=0.017
# >epoch=3302, lrate=0.050, error=0.017
# >epoch=3303, lrate=0.050, error=0.017
# >epoch=3304, lrate=0.050, error=0.017
# >epoch=3305, lrate=0.050, error=0.017
# >epoch=3306, lrate=0.050, error=0.017
# >epoch=3307, lrate=0.050, error=0.017
# >epoch=3308, lrate=0.050, error=0.017
# >epoch=3309, lrate=0.050, error=0.017
# >epoch=3310, lrate=0.050, error=0.017
# >epoch=3311, lrate=0.050, error=0.017
# >epoch=3312, lrate=0.050, error=0.017
# >epoch=3313, lrate=0.050, error=0.017
# >epoch=3314, lrate=0.050, error=0.017
# >epoch=3315, lrate=0.050, error=0.017
# >epoch=3316, lrate=0.050, error=0.017
# >epoch=3317, lrate=0.050, error=0.017
# >epoch=3318, lrate=0.050, error=0.017
# >epoch=3319, lrate=0.050, error=0.017
# >epoch=3320, lrate=0.050, error=0.017
# >epoch=3321, lrate=0.050, error=0.017
# >epoch=3322, lrate=0.050, error=0.017
# >epoch=3323, lrate=0.050, error=0.017
# >epoch=3324, lrate=0.050, error=0.017
# >epoch=3325, lrate=0.050, error=0.017
# >epoch=3326, lrate=0.050, error=0.017
# >epoch=3327, lrate=0.050, error=0.017
# >epoch=3328, lrate=0.050, error=0.017
# >epoch=3329, lrate=0.050, error=0.017
# >epoch=3330, lrate=0.050, error=0.017
# >epoch=3331, lrate=0.050, error=0.017
# >epoch=3332, lrate=0.050, error=0.017
# >epoch=3333, lrate=0.050, error=0.017
# >epoch=3334, lrate=0.050, error=0.017
# >epoch=3335, lrate=0.050, error=0.017
# >epoch=3336, lrate=0.050, error=0.017
# >epoch=3337, lrate=0.050, error=0.017
# >epoch=3338, lrate=0.050, error=0.017
# >epoch=3339, lrate=0.050, error=0.017
# >epoch=3340, lrate=0.050, error=0.017
# >epoch=3341, lrate=0.050, error=0.017
# >epoch=3342, lrate=0.050, error=0.017
# >epoch=3343, lrate=0.050, error=0.017
# >epoch=3344, lrate=0.050, error=0.017
# >epoch=3345, lrate=0.050, error=0.017
# >epoch=3346, lrate=0.050, error=0.017
# >epoch=3347, lrate=0.050, error=0.017
# >epoch=3348, lrate=0.050, error=0.017
# >epoch=3349, lrate=0.050, error=0.017
# >epoch=3350, lrate=0.050, error=0.017
# >epoch=3351, lrate=0.050, error=0.017
# >epoch=3352, lrate=0.050, error=0.017
# >epoch=3353, lrate=0.050, error=0.017
# >epoch=3354, lrate=0.050, error=0.017
# >epoch=3355, lrate=0.050, error=0.017
# >epoch=3356, lrate=0.050, error=0.017
# >epoch=3357, lrate=0.050, error=0.017
# >epoch=3358, lrate=0.050, error=0.017
# >epoch=3359, lrate=0.050, error=0.017
# >epoch=3360, lrate=0.050, error=0.017
# >epoch=3361, lrate=0.050, error=0.017
# >epoch=3362, lrate=0.050, error=0.017
# >epoch=3363, lrate=0.050, error=0.017
# >epoch=3364, lrate=0.050, error=0.017
# >epoch=3365, lrate=0.050, error=0.017
# >epoch=3366, lrate=0.050, error=0.017
# >epoch=3367, lrate=0.050, error=0.017
# >epoch=3368, lrate=0.050, error=0.017
# >epoch=3369, lrate=0.050, error=0.017
# >epoch=3370, lrate=0.050, error=0.017
# >epoch=3371, lrate=0.050, error=0.017
# >epoch=3372, lrate=0.050, error=0.017
# >epoch=3373, lrate=0.050, error=0.017
# >epoch=3374, lrate=0.050, error=0.017
# >epoch=3375, lrate=0.050, error=0.017
# >epoch=3376, lrate=0.050, error=0.017
# >epoch=3377, lrate=0.050, error=0.017
# >epoch=3378, lrate=0.050, error=0.017
# >epoch=3379, lrate=0.050, error=0.017
# >epoch=3380, lrate=0.050, error=0.017
# >epoch=3381, lrate=0.050, error=0.017
# >epoch=3382, lrate=0.050, error=0.017
# >epoch=3383, lrate=0.050, error=0.017
# >epoch=3384, lrate=0.050, error=0.017
# >epoch=3385, lrate=0.050, error=0.017
# >epoch=3386, lrate=0.050, error=0.017
# >epoch=3387, lrate=0.050, error=0.017
# >epoch=3388, lrate=0.050, error=0.017
# >epoch=3389, lrate=0.050, error=0.017
# >epoch=3390, lrate=0.050, error=0.017
# >epoch=3391, lrate=0.050, error=0.017
# >epoch=3392, lrate=0.050, error=0.017
# >epoch=3393, lrate=0.050, error=0.017
# >epoch=3394, lrate=0.050, error=0.017
# >epoch=3395, lrate=0.050, error=0.017
# >epoch=3396, lrate=0.050, error=0.017
# >epoch=3397, lrate=0.050, error=0.017
# >epoch=3398, lrate=0.050, error=0.017
# >epoch=3399, lrate=0.050, error=0.017
# >epoch=3400, lrate=0.050, error=0.017
# >epoch=3401, lrate=0.050, error=0.017
# >epoch=3402, lrate=0.050, error=0.017
# >epoch=3403, lrate=0.050, error=0.017
# >epoch=3404, lrate=0.050, error=0.017
# >epoch=3405, lrate=0.050, error=0.017
# >epoch=3406, lrate=0.050, error=0.017
# >epoch=3407, lrate=0.050, error=0.017
# >epoch=3408, lrate=0.050, error=0.017
# >epoch=3409, lrate=0.050, error=0.017
# >epoch=3410, lrate=0.050, error=0.017
# >epoch=3411, lrate=0.050, error=0.017
# >epoch=3412, lrate=0.050, error=0.017
# >epoch=3413, lrate=0.050, error=0.017
# >epoch=3414, lrate=0.050, error=0.017
# >epoch=3415, lrate=0.050, error=0.017
# >epoch=3416, lrate=0.050, error=0.017
# >epoch=3417, lrate=0.050, error=0.017
# >epoch=3418, lrate=0.050, error=0.017
# >epoch=3419, lrate=0.050, error=0.017
# >epoch=3420, lrate=0.050, error=0.017
# >epoch=3421, lrate=0.050, error=0.017
# >epoch=3422, lrate=0.050, error=0.017
# >epoch=3423, lrate=0.050, error=0.017
# >epoch=3424, lrate=0.050, error=0.017
# >epoch=3425, lrate=0.050, error=0.017
# >epoch=3426, lrate=0.050, error=0.017
# >epoch=3427, lrate=0.050, error=0.017
# >epoch=3428, lrate=0.050, error=0.017
# >epoch=3429, lrate=0.050, error=0.017
# >epoch=3430, lrate=0.050, error=0.017
# >epoch=3431, lrate=0.050, error=0.017
# >epoch=3432, lrate=0.050, error=0.017
# >epoch=3433, lrate=0.050, error=0.017
# >epoch=3434, lrate=0.050, error=0.017
# >epoch=3435, lrate=0.050, error=0.017
# >epoch=3436, lrate=0.050, error=0.017
# >epoch=3437, lrate=0.050, error=0.017
# >epoch=3438, lrate=0.050, error=0.017
# >epoch=3439, lrate=0.050, error=0.017
# >epoch=3440, lrate=0.050, error=0.017
# >epoch=3441, lrate=0.050, error=0.017
# >epoch=3442, lrate=0.050, error=0.017
# >epoch=3443, lrate=0.050, error=0.017
# >epoch=3444, lrate=0.050, error=0.017
# >epoch=3445, lrate=0.050, error=0.017
# >epoch=3446, lrate=0.050, error=0.017
# >epoch=3447, lrate=0.050, error=0.017
# >epoch=3448, lrate=0.050, error=0.017
# >epoch=3449, lrate=0.050, error=0.017
# >epoch=3450, lrate=0.050, error=0.017
# >epoch=3451, lrate=0.050, error=0.017
# >epoch=3452, lrate=0.050, error=0.017
# >epoch=3453, lrate=0.050, error=0.017
# >epoch=3454, lrate=0.050, error=0.017
# >epoch=3455, lrate=0.050, error=0.017
# >epoch=3456, lrate=0.050, error=0.017
# >epoch=3457, lrate=0.050, error=0.017
# >epoch=3458, lrate=0.050, error=0.017
# >epoch=3459, lrate=0.050, error=0.017
# >epoch=3460, lrate=0.050, error=0.017
# >epoch=3461, lrate=0.050, error=0.017
# >epoch=3462, lrate=0.050, error=0.017
# >epoch=3463, lrate=0.050, error=0.017
# >epoch=3464, lrate=0.050, error=0.017
# >epoch=3465, lrate=0.050, error=0.017
# >epoch=3466, lrate=0.050, error=0.017
# >epoch=3467, lrate=0.050, error=0.017
# >epoch=3468, lrate=0.050, error=0.017
# >epoch=3469, lrate=0.050, error=0.017
# >epoch=3470, lrate=0.050, error=0.017
# >epoch=3471, lrate=0.050, error=0.017
# >epoch=3472, lrate=0.050, error=0.017
# >epoch=3473, lrate=0.050, error=0.017
# >epoch=3474, lrate=0.050, error=0.017
# >epoch=3475, lrate=0.050, error=0.017
# >epoch=3476, lrate=0.050, error=0.017
# >epoch=3477, lrate=0.050, error=0.017
# >epoch=3478, lrate=0.050, error=0.017
# >epoch=3479, lrate=0.050, error=0.017
# >epoch=3480, lrate=0.050, error=0.017
# >epoch=3481, lrate=0.050, error=0.017
# >epoch=3482, lrate=0.050, error=0.017
# >epoch=3483, lrate=0.050, error=0.017
# >epoch=3484, lrate=0.050, error=0.017
# >epoch=3485, lrate=0.050, error=0.017
# >epoch=3486, lrate=0.050, error=0.017
# >epoch=3487, lrate=0.050, error=0.017
# >epoch=3488, lrate=0.050, error=0.017
# >epoch=3489, lrate=0.050, error=0.017
# >epoch=3490, lrate=0.050, error=0.017
# >epoch=3491, lrate=0.050, error=0.017
# >epoch=3492, lrate=0.050, error=0.017
# >epoch=3493, lrate=0.050, error=0.017
# >epoch=3494, lrate=0.050, error=0.017
# >epoch=3495, lrate=0.050, error=0.017
# >epoch=3496, lrate=0.050, error=0.017
# >epoch=3497, lrate=0.050, error=0.017
# >epoch=3498, lrate=0.050, error=0.017
# >epoch=3499, lrate=0.050, error=0.017
# >epoch=3500, lrate=0.050, error=0.017
# >epoch=3501, lrate=0.050, error=0.017
# >epoch=3502, lrate=0.050, error=0.017
# >epoch=3503, lrate=0.050, error=0.017
# >epoch=3504, lrate=0.050, error=0.017
# >epoch=3505, lrate=0.050, error=0.017
# >epoch=3506, lrate=0.050, error=0.017
# >epoch=3507, lrate=0.050, error=0.017
# >epoch=3508, lrate=0.050, error=0.017
# >epoch=3509, lrate=0.050, error=0.017
# >epoch=3510, lrate=0.050, error=0.017
# >epoch=3511, lrate=0.050, error=0.017
# >epoch=3512, lrate=0.050, error=0.017
# >epoch=3513, lrate=0.050, error=0.017
# >epoch=3514, lrate=0.050, error=0.017
# >epoch=3515, lrate=0.050, error=0.017
# >epoch=3516, lrate=0.050, error=0.017
# >epoch=3517, lrate=0.050, error=0.017
# >epoch=3518, lrate=0.050, error=0.017
# >epoch=3519, lrate=0.050, error=0.017
# >epoch=3520, lrate=0.050, error=0.017
# >epoch=3521, lrate=0.050, error=0.017
# >epoch=3522, lrate=0.050, error=0.017
# >epoch=3523, lrate=0.050, error=0.017
# >epoch=3524, lrate=0.050, error=0.017
# >epoch=3525, lrate=0.050, error=0.017
# >epoch=3526, lrate=0.050, error=0.017
# >epoch=3527, lrate=0.050, error=0.017
# >epoch=3528, lrate=0.050, error=0.017
# >epoch=3529, lrate=0.050, error=0.017
# >epoch=3530, lrate=0.050, error=0.017
# >epoch=3531, lrate=0.050, error=0.017
# >epoch=3532, lrate=0.050, error=0.017
# >epoch=3533, lrate=0.050, error=0.017
# >epoch=3534, lrate=0.050, error=0.017
# >epoch=3535, lrate=0.050, error=0.017
# >epoch=3536, lrate=0.050, error=0.017
# >epoch=3537, lrate=0.050, error=0.017
# >epoch=3538, lrate=0.050, error=0.017
# >epoch=3539, lrate=0.050, error=0.017
# >epoch=3540, lrate=0.050, error=0.017
# >epoch=3541, lrate=0.050, error=0.017
# >epoch=3542, lrate=0.050, error=0.017
# >epoch=3543, lrate=0.050, error=0.017
# >epoch=3544, lrate=0.050, error=0.017
# >epoch=3545, lrate=0.050, error=0.017
# >epoch=3546, lrate=0.050, error=0.017
# >epoch=3547, lrate=0.050, error=0.017
# >epoch=3548, lrate=0.050, error=0.017
# >epoch=3549, lrate=0.050, error=0.017
#
# Testing the network:
# Expected=35.0, Predicted=46.748
# Expected=95.0, Predicted=93.117
# Expected=78.0, Predicted=72.308
# Expected=154.0, Predicted=157.452
# Expected=101.0, Predicted=101.645
# Expected=160.0, Predicted=159.426
# Expected=161.0, Predicted=160.535
# Expected=110.0, Predicted=114.141
# Expected=177.0, Predicted=165.542
# Expected=106.0, Predicted=106.558

# %%
# Function to normalize a new input row based on min-max values from the training set
def normalize_input(input_row, min_max):
	return [(input_row[i] - min_max[i][0]) / (min_max[i][1] - min_max[i][0]) for i in range(len(input_row))]

def denormalize(value, min_val, max_val):
    return value * (max_val - min_val) + min_val

def forward_propagate2(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs

# Function to test new inputs with the trained network
def predict_sum(network, input1, input2, min_max):
	# Prepare the input in the normalized form
	input_row = normalize_input([input1, input2], min_max)
	# Forward propagate through the network
	outputs = forward_propagate2(network, input_row)
	# Denormalize the output
	predicted_sum = denormalize(outputs[0], min_max[-1][0], min_max[-1][1])
	print(f"Input1={input1}, Input2={input2}, Predicted Sum={predicted_sum:.3f}")

# Example usage
input1 = int(input("Enter a small integer: "))
input2 = int(input("Enter another small integer: "))
predict_sum(network, input1, input2, min_max)
# Out:
# Enter a small integer: 48
# Enter another small integer: 92
# Input1=48, Input2=92, Predicted Sum=148.350

# %%
3
